# %% [markdown]
# # Ejemplo: Trastornos Neurocognitivos y Demencia en América Latina e Iberoamérica (2000-202
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/juanmoisesd/trastornos-neurocognitivos-demencia-america-latina-2000-2025/blob/main/EXAMPLE_NOTEBOOK.ipynb)
#
# **DOI:** https://doi.org/10.5281/zenodo.19211345 | **Author:** de la Serna, Juan Moisés

# %%
# !pip install pandas matplotlib seaborn numpy -q
import pandas as pd,matplotlib.pyplot as plt,seaborn as sns,numpy as np
plt.style.use("seaborn-v0_8-whitegrid")
print("Ready")

# %%
# Full data: https://doi.org/10.5281/zenodo.19211345
np.random.seed(42)
cc=["Brazil","Mexico","Argentina","Colombia","Chile","Peru"]
rows=[{"country":c,"year":y,"value":round(np.random.uniform(8,25)+i*0.3,2)} for c in cc for i,y in enumerate(range(2015,2026))]
df=pd.DataFrame(rows)
df.head()

# %%
fig,ax=plt.subplots(figsize=(10,4))
for c in cc:
    s=df[df.country==c]
    ax.plot(s.year,s.value,marker="o",ms=3,label=c)
ax.set_title("Trastornos Neurocognitivos y Demencia en América L",fontweight="bold")
ax.legend(fontsize=8,ncol=3)
plt.tight_layout()
plt.savefig("example_plot.png",dpi=150,bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Cite
# ```
# de la Serna, Juan Moisés (2025). Trastornos Neurocognitivos y Demencia en América Latina e Iberoamérica (2000-202. Zenodo. https://doi.org/10.5281/zenodo.19211345
# ```
#
# [Zenodo](https://doi.org/10.5281/zenodo.19211345) | [GitHub](https://github.com/juanmoisesd/trastornos-neurocognitivos-demencia-america-latina-2000-2025) | [Colab](https://colab.research.google.com/github/juanmoisesd/trastornos-neurocognitivos-demencia-america-latina-2000-2025/blob/main/EXAMPLE_NOTEBOOK.ipynb)
