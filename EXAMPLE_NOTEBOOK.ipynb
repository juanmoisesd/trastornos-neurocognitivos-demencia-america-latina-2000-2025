# %% [markdown]
# # Análisis de Ejemplo: Trastornos Neurocognitivos y Demencia en América Latina e Iberoamérica (2000-202
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/juanmoisesd/trastornos-neurocognitivos-demencia-america-latina-2000-2025/blob/main/EXAMPLE_NOTEBOOK.ipynb)
#
# **DOI:** https://doi.org/10.5281/zenodo.19211345
# **GitHub:** https://github.com/juanmoisesd/trastornos-neurocognitivos-demencia-america-latina-2000-2025
# **Autor:** de la Serna, Juan Moisés

# %% [markdown]
# ## 1. Configuración

# %%
# !pip install pandas matplotlib seaborn numpy -q
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
plt.style.use("seaborn-v0_8-whitegrid")
print("✅ Ready")

# %% [markdown]
# ## 2. Datos de muestra

# %%
# Descargar desde Zenodo: https://doi.org/10.5281/zenodo.19211345
np.random.seed(42)
countries = ["Brazil","Mexico","Argentina","Colombia","Chile","Peru","Venezuela","Ecuador"]
years = list(range(2015, 2026))
rows = []
for c in countries:
    base = np.random.uniform(8,25)
    for i,y in enumerate(years):
        rows.append({"pais":c,"anio":y,"value":round(base+i*np.random.uniform(0.1,0.8)+np.random.normal(0,0.5),2),"n":int(np.random.uniform(500,5000))})
df = pd.DataFrame(rows)
print(f"Shape: {df.shape}")
df.head()

# %% [markdown]
# ## 3. Visualización

# %%
fig,axes=plt.subplots(1,2,figsize=(14,5))
for c in countries:
    s=df[df["pais"]==c]
    axes[0].plot(s["anio"],s["value"],marker="o",ms=3,label=c)
axes[0].set_title("Tendencia por País",fontsize=13,fontweight="bold")
axes[0].legend(fontsize=7,ncol=2)
pivot=df.pivot_table(values="value",index="pais",columns="anio",aggfunc="mean").round(1)
sns.heatmap(pivot,ax=axes[1],cmap="YlOrRd",annot=True,fmt=".1f",annot_kws={"size":7},linewidths=0.5)
axes[1].set_title("Mapa de Calor",fontsize=13,fontweight="bold")
plt.tight_layout()
plt.savefig("example_plot.png",dpi=150,bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Citación
#
# ```
# de la Serna, Juan Moisés (2025). Trastornos Neurocognitivos y Demencia en América Latina e Iberoamérica (2000-2025). Zenodo. https://doi.org/10.5281/zenodo.19211345
# ```
#
# 📦 **Datos completos:** https://doi.org/10.5281/zenodo.19211345
# 🐙 **GitHub:** https://github.com/juanmoisesd/trastornos-neurocognitivos-demencia-america-latina-2000-2025
