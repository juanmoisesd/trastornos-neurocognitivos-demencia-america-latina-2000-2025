# %% [markdown]
# # Trastornos Neurocognitivos y Demencia en América Latina e Iberoamérica (2000-2025)
#
# **DOI:** https://doi.org/10.5281/zenodo.19211345
# **Autor:** de la Serna, Juan Moisés
# **Año:** 2025

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

print("Análisis: Trastornos Neurocognitivos LATAM 2000-2025")

# %% [markdown]
# ## 1. Prevalencia de Demencia por País
#
# Análisis de las tasas de prevalencia en los principales países de América Latina.

# %%
# df_prevalencia = pd.read_csv("prevalencia_demencia.csv")
# df_prevalencia.head()

# %% [markdown]
# ## 2. Factores de Riesgo
#
# Exploración de los factores de riesgo modificables y no modificables.

# %%
# df_riesgo = pd.read_csv("factores_riesgo.csv")
# df_riesgo.describe()

# %% [markdown]
# ## Cómo citar
#
# ```
# de la Serna, Juan Moisés (2025). Trastornos Neurocognitivos y Demencia en América Latina e Iberoamérica (2000-2025). Zenodo. https://doi.org/10.5281/zenodo.19211345
# ```
